# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#교통수단별 입국

# %%
#file_used 1 = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/monthly_statistical_report/202001.xlsx
#file_used 2 = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/monthly_statistical_report/202002.xlsx
#file_used 3 = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/monthly_statistical_report/202003.xlsx
#file_used 4 = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/monthly_statistical_report/202004.xlsx
#file_used 5 = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/monthly_statistical_report/202005.xlsx
month1 = pd.read_excel('/content/202001.xlsx', sheet_name = '교통수단별 입국(1월)', encoding = 'utf-8')
month2 = pd.read_excel('/content/202002.xlsx', sheet_name = '교통수단별 입국(2월)', encoding = 'utf-8')
month3 = pd.read_excel('/content/202003.xlsx', sheet_name = '교통수단별 입국(3월)', encoding = 'utf-8')
month4 = pd.read_excel('/content/202004.xlsx', sheet_name = '교통수단별 입국(4월)', encoding = 'utf-8')
month5 = pd.read_excel('/content/202005.xlsx', sheet_name = '교통수단별 입국(5월)', encoding = 'utf-8')
df1 = month1[2:3]
df2 = month2[2:3]
df3 = month3[2:3]
df4 = month4[2:3]
df5 = month5[2:3]
a = df1.append(df2)
b = a.append(df3)
c = b.append(df4)
d = c.append(df5)
d_drop = d.drop(['교통수단별 국적별 입국 (2020년 1월)', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', '교통수단별 국적별 입국  (2020년 2월)', '교통수단별 국적별 입국  (2020년 3월)', '교통수단별 국적별 입국  (2020년 4월)', '교통수단별 국적별 입국  (2020년 5월)'], axis = 1)
col_name = ['Incheon Airport', 'growth rate1', 'Gimhae Airport', 'growth rate2', 'Kimpo Airport', 'growth rate3','Jeju Airport', 'growth rate4','Airport-etc', 'growth rate5', 'Airport Subtotal', 'growth rate6','Busan Port', 'growth rate7','Incheon Port', 'growth rate8','Jeju Port', 'growth rate9','Port-etc', 'growth rate10','Port Subtotal','growth rate11']
d_drop.columns = col_name
index_name = ['2020. 1.','2020. 2.','2020. 3.','2020. 4.','2020. 5.']
d_drop.index = index_name
d_drop
# Out:
#          Incheon Airport growth rate1  ... Port Subtotal growth rate11
# 2020. 1.          894553         20.9  ...         85172         -27.6
# 2020. 2.          519187        -37.5  ...         23308         -73.7
# 2020. 3.           67255        -93.5  ...          9187         -93.9
# 2020. 4.           25380        -97.6  ...          3641         -98.1
# 2020. 5.           25410        -97.3  ...          5120         -97.3
#
# [5 rows x 22 columns]

# %%
#교통수단별 입국-공항

# %%
#수
fig, ax = plt.subplots(6, 1, figsize=(20, 20))

#Incheon Airport
ax[0].plot(d_drop['Incheon Airport'], color='C0') 
ax[0].set_title("Incheon Airport(unit=persons)") 
ax[0].set_xlabel("time") 
ax[0].set_ylabel("figures")

#Gimhae Airport
ax[1].plot(d_drop['Gimhae Airport'], color='C1') 
ax[1].set_title("Gimhae Airport(unit=persons)") 
ax[1].set_xlabel("time") 
ax[1].set_ylabel("figures") 

#Kimpo Airport
ax[2].plot(d_drop['Kimpo Airport'], color='G') 
ax[2].set_title("Kimpo Airport(unit=persons)") 
ax[2].set_xlabel("time") 
ax[2].set_ylabel("figures") 

#Jeju Airport
ax[3].plot(d_drop['Jeju Airport'], color='R') 
ax[3].set_title("Jeju Airport(unit=persons)") 
ax[3].set_xlabel("time") 
ax[3].set_ylabel("figures") 

#Airport-etc
ax[4].plot(d_drop['Airport-etc'], color='y') 
ax[4].set_title("Airport-etc(unit=persons)") 
ax[4].set_xlabel("time") 
ax[4].set_ylabel("figures") 

#Airport Subtotal
ax[5].plot(d_drop['Airport Subtotal'], color='m') 
ax[5].set_title("Airport Subtotal(unit=persons)") 
ax[5].set_xlabel("time") 
ax[5].set_ylabel("figures") 
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py:125: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#성장률
fig, ax = plt.subplots(6, 1, figsize=(20, 20))

#Incheon Airport growth rate
ax[0].plot(d_drop['growth rate1'], color='C0') 
ax[0].set_title("Incheon Airport growth rate(unit=%)") 
ax[0].set_xlabel("time") 
ax[0].set_ylabel("figures")

#Gimhae Airport growth rate
ax[1].plot(d_drop['growth rate2'], color='C1') 
ax[1].set_title("Gimhae Airport growth rate(unit=%)") 
ax[1].set_xlabel("time") 
ax[1].set_ylabel("figures") 

#Gimpo Airport growth rate
ax[2].plot(d_drop['growth rate3'], color='G') 
ax[2].set_title("Gimpo Airport growth rate(unit=%)") 
ax[2].set_xlabel("time") 
ax[2].set_ylabel("figures") 

#Jeju Airport growth rate
ax[3].plot(d_drop['growth rate4'], color='R') 
ax[3].set_title("Jeju Airport growth rate(unit=%)") 
ax[3].set_xlabel("time") 
ax[3].set_ylabel("figures") 

#Airport-etc growth rate
ax[4].plot(d_drop['growth rate5'], color='y') 
ax[4].set_title("Airport-etc growth rate(unit=%)") 
ax[4].set_xlabel("time") 
ax[4].set_ylabel("figures") 

#Airport Subtotal growth rate
ax[5].plot(d_drop['growth rate6'], color='m') 
ax[5].set_title("Airport Subtotal growth rate(unit=%)") 
ax[5].set_xlabel("time") 
ax[5].set_ylabel("figures") 
plt.show()

# %%
#교통수단별 입국-항구

# %%
#수
fig, ax = plt.subplots(5, 1, figsize=(20, 20))

#Busan Port
ax[0].plot(d_drop['Busan Port'], color='C0') 
ax[0].set_title("Busan Port(unit=persons)") 
ax[0].set_xlabel("time") 
ax[0].set_ylabel("figures")

#Incehon Port
ax[1].plot(d_drop['Incheon Port'], color='C1') 
ax[1].set_title("Incheon Port(unit=persons)") 
ax[1].set_xlabel("time") 
ax[1].set_ylabel("figures") 

#Jeju Port
ax[2].plot(d_drop['Jeju Port'], color='G') 
ax[2].set_title("Jeju Port(unit=persons)") 
ax[2].set_xlabel("time") 
ax[2].set_ylabel("figures") 

#Port-etc
ax[3].plot(d_drop['Port-etc'], color='R') 
ax[3].set_title("Port-etc(unit=persons)") 
ax[3].set_xlabel("time") 
ax[3].set_ylabel("figures") 

#Port Subtotal
ax[4].plot(d_drop['Port Subtotal'], color='y') 
ax[4].set_title("Port Subtotal(unit=persons)") 
ax[4].set_xlabel("time") 
ax[4].set_ylabel("figures") 
plt.show()

# %%
#성장률
fig, ax = plt.subplots(5, 1, figsize=(20, 20))

#Busan Port growth rate
ax[0].plot(d_drop['growth rate7'], color='C0') 
ax[0].set_title("Busan Port growth rate(unit=%)") 
ax[0].set_xlabel("time") 
ax[0].set_ylabel("figures")

#Incehon Port growth rate
ax[1].plot(d_drop['growth rate8'], color='C1') 
ax[1].set_title("Incehon Port growth rate(unit=%)") 
ax[1].set_xlabel("time") 
ax[1].set_ylabel("figures") 

#Jeju Port growth rate
ax[2].plot(d_drop['growth rate9'], color='G') 
ax[2].set_title("Jeju Port growth rate(unit=%)") 
ax[2].set_xlabel("time") 
ax[2].set_ylabel("figures") 

#Port-etc growth rate
ax[3].plot(d_drop['growth rate10'], color='R') 
ax[3].set_title("Port-etc growth rate(unit=%)") 
ax[3].set_xlabel("time") 
ax[3].set_ylabel("figures") 

#Port Subtotal growth rate
ax[4].plot(d_drop['growth rate11'], color='y') 
ax[4].set_title("Port Subtotal growth rate(unit=%)") 
ax[4].set_xlabel("time") 
ax[4].set_ylabel("figures") 
plt.show()

# %%
#교통수단별 출국

# %%
#file_used = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/monthly_statistical_report/202005.xlsx
month_5 = pd.read_excel('/content/202005.xlsx', sheet_name = '교통수단별 출국', encoding = 'utf-8')
df6 = month_5[2:8]
df6_drop = df6.drop(['교통수단별출국', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'], axis = 1)
col_name = ['Incheon Airport', 'growth rate1', 'Gimhae Airport', 'growth rate2', 'Kimpo Airport', 'growth rate3','Jeju Airport', 'growth rate4','Airport-etc', 'growth rate5', 'Airport Subtotal', 'growth rate6','Busan Port', 'growth rate7','Incheon Port', 'growth rate8','Jeju Port', 'growth rate9','Port-etc', 'growth rate10','Port Subtotal','growth rate11']
df6_drop.columns = col_name
index_name = ['total', '2020. 1.','2020. 2.','2020. 3.','2020. 4.','2020. 5.']
df6_drop.index = index_name
df6_drop
# Out:
#          Incheon Airport growth rate1  ... Port Subtotal growth rate11
# total            2928400        -67.7  ...         91531         -77.5
# 2020. 1.         1925217         -9.1  ...         32934         -59.1
# 2020. 2.          844188        -55.3  ...         19769           -75
# 2020. 3.          115338        -93.2  ...         13366         -82.6
# 2020. 4.           19122        -98.8  ...         12253         -85.5
# 2020. 5.           24535        -98.6  ...         13209         -84.6
#
# [6 rows x 22 columns]

# %%
#교통수단별 출국-공항

# %%
#수
fig, ax = plt.subplots(6, 1, figsize=(20, 20))

#Incheon Airport
ax[0].plot(df6_drop['Incheon Airport'], color='C0') 
ax[0].set_title("Incheon Airport(unit=persons)") 
ax[0].set_xlabel("time") 
ax[0].set_ylabel("figures")

#Gimhae Airport
ax[1].plot(df6_drop['Gimhae Airport'], color='C1') 
ax[1].set_title("Gimhae Airport(unit=persons)") 
ax[1].set_xlabel("time") 
ax[1].set_ylabel("figures") 

#Kimpo Airport
ax[2].plot(df6_drop['Kimpo Airport'], color='G') 
ax[2].set_title("Kimpo Airport(unit=persons)") 
ax[2].set_xlabel("time") 
ax[2].set_ylabel("figures") 

#Jeju Airport
ax[3].plot(df6_drop['Jeju Airport'], color='R') 
ax[3].set_title("Jeju Airport(unit=persons)") 
ax[3].set_xlabel("time") 
ax[3].set_ylabel("figures") 

#Airport-etc
ax[4].plot(df6_drop['Airport-etc'], color='y') 
ax[4].set_title("Airport-etc(unit=persons)") 
ax[4].set_xlabel("time") 
ax[4].set_ylabel("figures") 

#Airport Subtotal
ax[5].plot(df6_drop['Airport Subtotal'], color='m') 
ax[5].set_title("Airport Subtotal(unit=persons)") 
ax[5].set_xlabel("time") 
ax[5].set_ylabel("figures") 
plt.show()

# %%
#성장률
fig, ax = plt.subplots(6, 1, figsize=(20, 20))

#Incheon Airport growth rate
ax[0].plot(df6_drop['growth rate1'], color='C0') 
ax[0].set_title("Incheon Airport growth rate(unit=%)") 
ax[0].set_xlabel("time") 
ax[0].set_ylabel("figures")

#Gimhae Airport growth rate
ax[1].plot(df6_drop['growth rate2'], color='C1') 
ax[1].set_title("Gimhae Airport growth rate(unit=%)") 
ax[1].set_xlabel("time") 
ax[1].set_ylabel("figures") 

#Gimpo Airport growth rate
ax[2].plot(df6_drop['growth rate3'], color='G') 
ax[2].set_title("Gimpo Airport growth rate(unit=%)") 
ax[2].set_xlabel("time") 
ax[2].set_ylabel("figures") 

#Jeju Airport growth rate
ax[3].plot(df6_drop['growth rate4'], color='R') 
ax[3].set_title("Jeju Airport growth rate(unit=%)") 
ax[3].set_xlabel("time") 
ax[3].set_ylabel("figures") 

#Airport-etc growth rate
ax[4].plot(df6_drop['growth rate5'], color='y') 
ax[4].set_title("Airport-etc growth rate(unit=%)") 
ax[4].set_xlabel("time") 
ax[4].set_ylabel("figures") 

#Airport Subtotal growth rate
ax[5].plot(df6_drop['growth rate6'], color='m') 
ax[5].set_title("Airport Subtotal growth rate(unit=%)") 
ax[5].set_xlabel("time") 
ax[5].set_ylabel("figures") 
plt.show()

# %%
#교통수단별 출국-항구

# %%
#수
fig, ax = plt.subplots(5, 1, figsize=(20, 20))

#Busan Port
ax[0].plot(df6_drop['Busan Port'], color='C0') 
ax[0].set_title("Busan Port(unit=persons)") 
ax[0].set_xlabel("time") 
ax[0].set_ylabel("figures")

#Incehon Port
ax[1].plot(df6_drop['Incheon Port'], color='C1') 
ax[1].set_title("Incheon Port(unit=persons)") 
ax[1].set_xlabel("time") 
ax[1].set_ylabel("figures") 

#Jeju Port
ax[2].plot(df6_drop['Jeju Port'], color='G') 
ax[2].set_title("Jeju Port(unit=persons)") 
ax[2].set_xlabel("time") 
ax[2].set_ylabel("figures") 

#Port-etc
ax[3].plot(df6_drop['Port-etc'], color='R') 
ax[3].set_title("Port-etc(unit=persons)") 
ax[3].set_xlabel("time") 
ax[3].set_ylabel("figures") 

#Port Subtotal
ax[4].plot(df6_drop['Port Subtotal'], color='y') 
ax[4].set_title("Port Subtotal(unit=persons)") 
ax[4].set_xlabel("time") 
ax[4].set_ylabel("figures") 
plt.show()

# %%
#성장률
fig, ax = plt.subplots(5, 1, figsize=(20, 20))

#Busan Port growth rate
ax[0].plot(df6_drop['growth rate7'], color='C0') 
ax[0].set_title("Busan Port growth rate(unit=%)") 
ax[0].set_xlabel("time") 
ax[0].set_ylabel("figures")

#Incehon Port growth rate
ax[1].plot(df6_drop['growth rate8'], color='C1') 
ax[1].set_title("Incehon Port growth rate(unit=%)") 
ax[1].set_xlabel("time") 
ax[1].set_ylabel("figures") 

#Jeju Port growth rate
ax[2].plot(df6_drop['growth rate9'], color='G') 
ax[2].set_title("Jeju Port growth rate(unit=%)") 
ax[2].set_xlabel("time") 
ax[2].set_ylabel("figures") 

#Port-etc growth rate
ax[3].plot(df6_drop['growth rate10'], color='R') 
ax[3].set_title("Port-etc growth rate(unit=%)") 
ax[3].set_xlabel("time") 
ax[3].set_ylabel("figures") 

#Port Subtotal growth rate
ax[4].plot(df6_drop['growth rate11'], color='y') 
ax[4].set_title("Port Subtotal growth rate(unit=%)") 
ax[4].set_xlabel("time") 
ax[4].set_ylabel("figures") 
plt.show()

# %%
#항공 전체 시계열 통계

# %%
#file_used = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/aviation/time_series_statistics_2019-2020.6.xlsx
data = pd.read_excel('/content/time_series_statistics_2019-2020.6.xlsx', sheet_name = '2019-2020.6', encoding = 'utf-8')
df8 = data[1:21]
df8_drop = df8.drop(['공항명', '연도', '월'], axis = 1)
col_name = ['flights(number)-arrival', 'flights(number)-departure', 'flights(number)-total', 'Passenger(persons)-arrival', 'Passenger(persons)-departure', 'Passenger(persons)-total', 'Cargo(ton)-arrival', 'Cargo(ton)-departure', 'Cargo(ton)-total']
df8_drop.columns = col_name
index_name = ['2019. 1.', '2019. 2.','2019. 3.','2019. 4.','2019. 5.','2019. 6.', '2019. 7.','2019. 8.','2019. 9.','2019.10.','2019.11.', '2019-total','2019.12.','2020.1.','2020.2.','2020.3.','2020.4.','2020.5.', '2020.6.', '2020-total']
df8_drop.index = index_name
df8_drop
# Out:
#            flights(number)-arrival  ... Cargo(ton)-total
# 2019. 1.                     38580  ...           382316
# 2019. 2.                     35057  ...           328546
# 2019. 3.                     38369  ...           396068
# 2019. 4.                     37647  ...           371192
# 2019. 5.                     39521  ...           370085
# 2019. 6.                     38841  ...           369680
# 2019. 7.                     40074  ...           376640
# 2019. 8.                     40718  ...           386244
# 2019. 9.                     36942  ...           368181
# 2019.10.                     38307  ...           397611
# 2019.11.                     36806  ...           392205
# 2019-total                   38565  ...           394679
# 2019.12.                    459427  ...      4.53345e+06
# 2020.1.                      39481  ...           371686
# 2020.2.                      29354  ...           314880
# ...

# %%
#항공 전체 시계열 통계-운항(편수)

# %%
a = df8_drop.drop(['Passenger(persons)-arrival', 'Passenger(persons)-departure', 'Passenger(persons)-total', 'Cargo(ton)-arrival', 'Cargo(ton)-departure', 'Cargo(ton)-total'], axis = 1)
plt.figure(figsize=(20,10))

# %%
#항공 전체 시계열 통계-승객(명)

# %%
b = df8_drop.drop(['flights(number)-arrival', 'flights(number)-departure', 'flights(number)-total',  'Cargo(ton)-arrival', 'Cargo(ton)-departure', 'Cargo(ton)-total'], axis = 1)
plt.figure(figsize=(20,10))
plt.ylabel('100 million')
plt.plot(b)

# %%
#항공 전체 시계열 통계-화물(톤)

# %%
c = df8_drop.drop(['flights(number)-arrival', 'flights(number)-departure', 'flights(number)-total', 'Passenger(persons)-arrival', 'Passenger(persons)-departure', 'Passenger(persons)-total'], axis = 1)
plt.figure(figsize=(20,10))
plt.plot(c)

# %%
#공항별 전년대비 통계-운항(편수)

# %%
#file_used = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/aviation/Year-on-year_by_airport_statisitcs_2020.1-6.xlsx
data1 = pd.read_excel('/content/Year-on-year_by_airport_statisitcs_2020.1-6.xlsx', sheet_name = '1월',encoding = 'utf-8')
data2 = pd.read_excel('/content/Year-on-year_by_airport_statisitcs_2020.1-6.xlsx', sheet_name = '2월',encoding = 'utf-8')
data3 = pd.read_excel('/content/Year-on-year_by_airport_statisitcs_2020.1-6.xlsx', sheet_name = '3월',encoding = 'utf-8')
data4 = pd.read_excel('/content/Year-on-year_by_airport_statisitcs_2020.1-6.xlsx', sheet_name = '4월',encoding = 'utf-8')
data5 = pd.read_excel('/content/Year-on-year_by_airport_statisitcs_2020.1-6.xlsx', sheet_name = '5월',encoding = 'utf-8')
data6 = pd.read_excel('/content/Year-on-year_by_airport_statisitcs_2020.1-6.xlsx', sheet_name = '6월',encoding = 'utf-8')
dt1 = data1[1:17]
dt1_drop = dt1.drop(['공항명', '여객(명)', 'Unnamed: 5', 'Unnamed: 6', '화물(ton)', 'Unnamed: 8', 'Unnamed: 9'], axis = 1)
col_name1 = ['2019.1', '2020.1', 'Increase/decrease']
dt1_drop.columns = col_name1
index_name1 = ['Gimpo', 'Gimhae', 'Jeju', 'Daegu', 'Gwangju', 'Muan', 'Cheongju', 'Yangyang', 'Yeosu', 'Ulsan', 'Sacheon', 'Pohang', 'Gunsan', 'Wonju', 'Incheon', 'total']
dt1_drop.index = index_name1
dt2 = data2[1:17]
dt2_drop = dt2.drop(['공항명', '여객(명)', 'Unnamed: 5', 'Unnamed: 6', '화물(ton)', 'Unnamed: 8', 'Unnamed: 9'], axis = 1)
col_name2 = ['2019.2', '2020.2', 'Increase/decrease']
dt2_drop.columns = col_name2
index_name1 = ['Gimpo', 'Gimhae', 'Jeju', 'Daegu', 'Gwangju', 'Muan', 'Cheongju', 'Yangyang', 'Yeosu', 'Ulsan', 'Sacheon', 'Pohang', 'Gunsan', 'Wonju', 'Incheon', 'total']
dt2_drop.index = index_name1
dt3 = data3[1:17]
dt3_drop = dt3.drop(['공항명', '여객(명)', 'Unnamed: 5', 'Unnamed: 6', '화물(ton)', 'Unnamed: 8', 'Unnamed: 9'], axis = 1)
col_name3 = ['2019.3', '2020.3', 'Increase/decrease']
dt3_drop.columns = col_name3
index_name1 = ['Gimpo', 'Gimhae', 'Jeju', 'Daegu', 'Gwangju', 'Muan', 'Cheongju', 'Yangyang', 'Yeosu', 'Ulsan', 'Sacheon', 'Pohang', 'Gunsan', 'Wonju', 'Incheon', 'total']
dt3_drop.index = index_name1
dt4 = data4[1:17]
dt4_drop = dt4.drop(['공항명', '여객(명)', 'Unnamed: 5', 'Unnamed: 6', '화물(ton)', 'Unnamed: 8', 'Unnamed: 9'], axis = 1)
col_name4 = ['2019.4', '2020.4', 'Increase/decrease']
dt4_drop.columns = col_name4
index_name1 = ['Gimpo', 'Gimhae', 'Jeju', 'Daegu', 'Gwangju', 'Muan', 'Cheongju', 'Yangyang', 'Yeosu', 'Ulsan', 'Sacheon', 'Pohang', 'Gunsan', 'Wonju', 'Incheon', 'total']
dt4_drop.index = index_name1
dt5 = data5[1:17]
dt5_drop = dt5.drop(['공항명', '여객(명)', 'Unnamed: 5', 'Unnamed: 6', '화물(ton)', 'Unnamed: 8', 'Unnamed: 9'], axis = 1)
col_name5 = ['2019.5', '2020.5', 'Increase/decrease']
dt5_drop.columns = col_name5
index_name1 = ['Gimpo', 'Gimhae', 'Jeju', 'Daegu', 'Gwangju', 'Muan', 'Cheongju', 'Yangyang', 'Yeosu', 'Ulsan', 'Sacheon', 'Pohang', 'Gunsan', 'Wonju', 'Incheon', 'total']
dt5_drop.index = index_name1
dt6 = data6[1:17]
dt6_drop = dt6.drop(['공항명', '여객(명)', 'Unnamed: 5', 'Unnamed: 6', '화물(ton)', 'Unnamed: 8', 'Unnamed: 9'], axis = 1)
col_name6 = ['2019.6', '2020.6', 'Increase/decrease']
dt6_drop.columns = col_name6
index_name1 = ['Gimpo', 'Gimhae', 'Jeju', 'Daegu', 'Gwangju', 'Muan', 'Cheongju', 'Yangyang', 'Yeosu', 'Ulsan', 'Sacheon', 'Pohang', 'Gunsan', 'Wonju', 'Incheon', 'total']
dt6_drop.index = index_name1
a1 = np.transpose(dt1_drop)
a2 = np.transpose(dt2_drop)
a3 = np.transpose(dt3_drop)
a4 = np.transpose(dt4_drop)
a5 = np.transpose(dt5_drop)
a6 = np.transpose(dt6_drop)
b1 = a1.append(a2)
b2 = b1.append(a3)
b3 = b2.append(a4)
b4 = b3.append(a5)
b5 = b4.append(a6)
b6 = np.transpose(b5)
b6
# Out:
#          2019.1 2020.1 Increase/decrease  ... 2019.6 2020.6 Increase/decrease
# Gimpo     11545  11805               2.3  ...  12010   9445             -21.4
# Gimhae     9786   9137              -6.6  ...   9566   3914             -59.1
# Jeju      14033  15139               7.9  ...  14769  11811               -20
# Daegu      2717   2160             -20.5  ...   2880   1062             -63.1
# Gwangju    1175   1169              -0.5  ...   1082   1221              12.8
# Muan        559    503               -10  ...    582      0                 0
# Cheongju   1652   1657               0.3  ...   1612   1105             -31.5
# Yangyang     29    264             810.3  ...     27    183             577.8
# Yeosu       422    428               1.4  ...    414    428               3.4
# Ulsan       538    534              -0.7  ...    508    348             -31.5
# Sacheon     162    164               1.2  ...    162      0                 0
# ...

# %%
#공항별 전년대비-운항(편수) 수 - 2019

# %%
b6_drop1 = b6.drop(['Increase/decrease'], axis = 1)
b6_drop1
b6__drop1 = b6_drop1.drop(['2020.1', '2020.2', '2020.3', '2020.4', '2020.5', '2020.6'], axis = 1)
b6__drop1.plot(kind = 'bar', figsize = (20,15), title = 'flights-2019(unit=number)')

# %%
#공항별 전년대비-운항(편수) 수 - 2020

# %%
b6_drop1 = b6.drop(['Increase/decrease'], axis = 1)
b6_drop1
b6__drop2 = b6_drop1.drop(['2019.1', '2019.2', '2019.3', '2019.4', '2019.5', '2019.6'], axis = 1)
b6__drop2.plot(kind = 'bar', figsize = (20,15), title = 'flights-2020(unit=number)')

# %%
#공항별 전년대비-운항(편수) 증감률

# %%
#양양(Yangyang) 제외
b6_drop2 = b6.drop(['2019.1', '2019.2', '2019.3', '2019.4', '2019.5', '2019.6', '2020.1', '2020.2', '2020.3', '2020.4', '2020.5', '2020.6'], axis = 1)
b6__drop2 = b6_drop2.drop(['Yangyang'])
b6__drop2.plot(kind = 'bar', figsize = (20, 15), title = 'flights-Increase/decrease(unit=%) : per month')

# %%
#공항별 전년대비-승객(명)

# %%
dt1_drop1 = dt1.drop(['공항명', '운항(편수)',	'Unnamed: 2',	'Unnamed: 3', '화물(ton)', 'Unnamed: 8', 'Unnamed: 9'], axis = 1)
col_name1 = ['2019.1', '2020.1', 'Increase/decrease']
dt1_drop1.columns = col_name1
index_name1 = ['Gimpo', 'Gimhae', 'Jeju', 'Daegu', 'Gwangju', 'Muan', 'Cheongju', 'Yangyang', 'Yeosu', 'Ulsan', 'Sacheon', 'Pohang', 'Gunsan', 'Wonju', 'Incheon', 'total']
dt1_drop1.index = index_name1
dt2_drop1 = dt2.drop(['공항명', '운항(편수)',	'Unnamed: 2',	'Unnamed: 3', '화물(ton)', 'Unnamed: 8', 'Unnamed: 9'], axis = 1)
col_name2 = ['2019.2', '2020.2', 'Increase/decrease']
dt2_drop1.columns = col_name2
index_name1 = ['Gimpo', 'Gimhae', 'Jeju', 'Daegu', 'Gwangju', 'Muan', 'Cheongju', 'Yangyang', 'Yeosu', 'Ulsan', 'Sacheon', 'Pohang', 'Gunsan', 'Wonju', 'Incheon', 'total']
dt2_drop1.index = index_name1
dt3_drop1 = dt3.drop(['공항명', '운항(편수)',	'Unnamed: 2',	'Unnamed: 3', '화물(ton)', 'Unnamed: 8', 'Unnamed: 9'], axis = 1)
col_name3 = ['2019.3', '2020.3', 'Increase/decrease']
dt3_drop1.columns = col_name3
index_name1 = ['Gimpo', 'Gimhae', 'Jeju', 'Daegu', 'Gwangju', 'Muan', 'Cheongju', 'Yangyang', 'Yeosu', 'Ulsan', 'Sacheon', 'Pohang', 'Gunsan', 'Wonju', 'Incheon', 'total']
dt3_drop1.index = index_name1
dt4_drop1 = dt4.drop(['공항명', '운항(편수)',	'Unnamed: 2',	'Unnamed: 3', '화물(ton)', 'Unnamed: 8', 'Unnamed: 9'], axis = 1)
col_name4 = ['2019.4', '2020.4', 'Increase/decrease']
dt4_drop1.columns = col_name4
index_name1 = ['Gimpo', 'Gimhae', 'Jeju', 'Daegu', 'Gwangju', 'Muan', 'Cheongju', 'Yangyang', 'Yeosu', 'Ulsan', 'Sacheon', 'Pohang', 'Gunsan', 'Wonju', 'Incheon', 'total']
dt4_drop1.index = index_name1
dt5_drop1 = dt5.drop(['공항명', '운항(편수)',	'Unnamed: 2',	'Unnamed: 3', '화물(ton)', 'Unnamed: 8', 'Unnamed: 9'], axis = 1)
col_name5 = ['2019.5', '2020.5', 'Increase/decrease']
dt5_drop1.columns = col_name5
index_name1 = ['Gimpo', 'Gimhae', 'Jeju', 'Daegu', 'Gwangju', 'Muan', 'Cheongju', 'Yangyang', 'Yeosu', 'Ulsan', 'Sacheon', 'Pohang', 'Gunsan', 'Wonju', 'Incheon', 'total']
dt5_drop1.index = index_name1
dt6_drop1 = dt6.drop(['공항명', '운항(편수)',	'Unnamed: 2',	'Unnamed: 3', '화물(ton)', 'Unnamed: 8', 'Unnamed: 9'], axis = 1)
col_name6 = ['2019.6', '2020.6', 'Increase/decrease']
dt6_drop1.columns = col_name6
index_name1 = ['Gimpo', 'Gimhae', 'Jeju', 'Daegu', 'Gwangju', 'Muan', 'Cheongju', 'Yangyang', 'Yeosu', 'Ulsan', 'Sacheon', 'Pohang', 'Gunsan', 'Wonju', 'Incheon', 'total']
dt6_drop1.index = index_name1
c1 = np.transpose(dt1_drop1)
c2 = np.transpose(dt2_drop1)
c3 = np.transpose(dt3_drop1)
c4 = np.transpose(dt4_drop1)
c5 = np.transpose(dt5_drop1)
c6 = np.transpose(dt6_drop1)
d1 = c1.append(c2)
d2 = d1.append(c3)
d3 = d2.append(c4)
d4 = d3.append(c5)
d5 = d4.append(c6)
d6 = np.transpose(d5)
d6
# Out:
#             2019.1    2020.1  ...   2020.6 Increase/decrease
# Gimpo      1966530   2077132  ...  1444483             -33.6
# Gimhae     1510402   1394866  ...   554583             -62.3
# Jeju       2372031   2612063  ...  1785615             -33.5
# Daegu       438339    340406  ...   138767             -67.5
# Gwangju     157399    174221  ...   160655              -7.5
# Muan         88169     75657  ...        0                 0
# Cheongju    263499    258155  ...   161475             -37.1
# Yangyang      4434     29127  ...    20357             736.4
# Yeosu        47624     50074  ...    51877              -4.1
# Ulsan        61800     70002  ...    42868               -30
# Sacheon      14276     16953  ...        0                 0
# Pohang        7350      6913  ...        0                 0
# Gunsan       17637     28421  ...        0                 0
# Wonju         7524      6943  ...        0                 0
# ...

# %%
#공항별 전년대비-승객(명) 수 - 2019

# %%
d6_drop1 = d6.drop(['Increase/decrease'], axis = 1)
d6_drop1
d6__drop1 = d6_drop1.drop(['2020.1', '2020.2', '2020.3', '2020.4', '2020.5', '2020.6'], axis = 1)
d6__drop1.plot(kind = 'bar', figsize = (20,15), title = 'passenger-2019(unit=persons)')

# %%
#공항별 전년대비-승객(명) 수 - 2020

# %%
d6_drop1 = d6.drop(['Increase/decrease'], axis = 1)
d6_drop1
d6__drop2 = d6_drop1.drop(['2019.1', '2019.2', '2019.3', '2019.4', '2019.5', '2019.6'], axis = 1)
d6__drop2.plot(kind = 'bar', figsize = (20,15), title = 'passenger-2020(unit=persons)')

# %%
#공항별 전년대비-승객(명) 증감률

# %%
#Yangyang(양양) 제외
d6_drop2 = d6.drop(['2019.1', '2019.2', '2019.3', '2019.4', '2019.5', '2019.6', '2020.1', '2020.2', '2020.3', '2020.4', '2020.5', '2020.6'], axis = 1)
d6__drop2 = d6_drop2.drop(['Yangyang'])
d6__drop2.plot(kind = 'bar', figsize = (20, 15), title = 'passenger-Increase/decrease(unit=persons) : per month')

# %%
#공항별 전년대비-화물(ton)

# %%
dt1_drop2 = dt1.drop(['공항명', '운항(편수)',	'Unnamed: 2',	'Unnamed: 3', '화물(ton)', 'Unnamed: 8', 'Unnamed: 9'], axis = 1)
col_name1 = ['2019.1', '2020.1', 'Increase/decrease']
dt1_drop2.columns = col_name1
index_name1 = ['Gimpo', 'Gimhae', 'Jeju', 'Daegu', 'Gwangju', 'Muan', 'Cheongju', 'Yangyang', 'Yeosu', 'Ulsan', 'Sacheon', 'Pohang', 'Gunsan', 'Wonju', 'Incheon', 'total']
dt1_drop2.index = index_name1
dt2_drop2 = dt2.drop(['공항명', '운항(편수)',	'Unnamed: 2',	'Unnamed: 3', '여객(명)',	'Unnamed: 5',	'Unnamed: 6'], axis = 1)
col_name2 = ['2019.2', '2020.2', 'Increase/decrease']
dt2_drop2.columns = col_name2
index_name1 = ['Gimpo', 'Gimhae', 'Jeju', 'Daegu', 'Gwangju', 'Muan', 'Cheongju', 'Yangyang', 'Yeosu', 'Ulsan', 'Sacheon', 'Pohang', 'Gunsan', 'Wonju', 'Incheon', 'total']
dt2_drop2.index = index_name1
dt3_drop2 = dt3.drop(['공항명', '운항(편수)',	'Unnamed: 2',	'Unnamed: 3', '여객(명)',	'Unnamed: 5',	'Unnamed: 6'], axis = 1)
col_name3 = ['2019.3', '2020.3', 'Increase/decrease']
dt3_drop2.columns = col_name3
index_name1 = ['Gimpo', 'Gimhae', 'Jeju', 'Daegu', 'Gwangju', 'Muan', 'Cheongju', 'Yangyang', 'Yeosu', 'Ulsan', 'Sacheon', 'Pohang', 'Gunsan', 'Wonju', 'Incheon', 'total']
dt3_drop2.index = index_name1
dt4_drop2 = dt4.drop(['공항명', '운항(편수)',	'Unnamed: 2',	'Unnamed: 3', '여객(명)',	'Unnamed: 5',	'Unnamed: 6'], axis = 1)
col_name4 = ['2019.4', '2020.4', 'Increase/decrease']
dt4_drop2.columns = col_name4
index_name1 = ['Gimpo', 'Gimhae', 'Jeju', 'Daegu', 'Gwangju', 'Muan', 'Cheongju', 'Yangyang', 'Yeosu', 'Ulsan', 'Sacheon', 'Pohang', 'Gunsan', 'Wonju', 'Incheon', 'total']
dt4_drop2.index = index_name1
dt5_drop2 = dt5.drop(['공항명', '운항(편수)',	'Unnamed: 2',	'Unnamed: 3', '여객(명)',	'Unnamed: 5',	'Unnamed: 6'], axis = 1)
col_name5 = ['2019.5', '2020.5', 'Increase/decrease']
dt5_drop2.columns = col_name5
index_name1 = ['Gimpo', 'Gimhae', 'Jeju', 'Daegu', 'Gwangju', 'Muan', 'Cheongju', 'Yangyang', 'Yeosu', 'Ulsan', 'Sacheon', 'Pohang', 'Gunsan', 'Wonju', 'Incheon', 'total']
dt5_drop2.index = index_name1
dt6_drop2 = dt6.drop(['공항명', '운항(편수)',	'Unnamed: 2',	'Unnamed: 3', '여객(명)',	'Unnamed: 5',	'Unnamed: 6'], axis = 1)
col_name6 = ['2019.6', '2020.6', 'Increase/decrease']
dt6_drop2.columns = col_name6
index_name1 = ['Gimpo', 'Gimhae', 'Jeju', 'Daegu', 'Gwangju', 'Muan', 'Cheongju', 'Yangyang', 'Yeosu', 'Ulsan', 'Sacheon', 'Pohang', 'Gunsan', 'Wonju', 'Incheon', 'total']
dt6_drop2.index = index_name1
e1 = np.transpose(dt1_drop2)
e2 = np.transpose(dt2_drop2)
e3 = np.transpose(dt3_drop2)
e4 = np.transpose(dt4_drop2)
e5 = np.transpose(dt5_drop2)
e6 = np.transpose(dt6_drop2)
f1 = e1.append(e2)
f2 = f1.append(e3)
f3 = f2.append(e4)
f4 = f3.append(e5)
f5 = f4.append(e6)
f6 = np.transpose(f5)
f6
# Out:
#             2019.1    2020.1  ...   2020.6 Increase/decrease
# Gimpo      1966530   2077132  ...   8943.5             -52.8
# Gimhae     1510402   1394866  ...   2366.2             -83.1
# Jeju       2372031   2612063  ...  12172.4             -38.6
# Daegu       438339    340406  ...    737.2             -74.7
# Gwangju     157399    174221  ...      638             -39.3
# Muan         88169     75657  ...        0                 0
# Cheongju    263499    258155  ...    761.5             -51.9
# Yangyang      4434     29127  ...       93             275.7
# Yeosu        47624     50074  ...    165.8             -27.4
# Ulsan        61800     70002  ...    135.1             -54.4
# Sacheon      14276     16953  ...        0                 0
# Pohang        7350      6913  ...        0                 0
# Gunsan       17637     28421  ...        0                 0
# Wonju         7524      6943  ...        0                 0
# ...

# %%
#공항별 전년대비-화물(ton) 수 - 2019

# %%
f6_drop1 = f6.drop(['Increase/decrease'], axis = 1)
f6_drop1
f6__drop1 = f6_drop1.drop(['2020.1', '2020.2', '2020.3', '2020.4', '2020.5', '2020.6'], axis = 1)
f6__drop1.plot(kind = 'bar', figsize = (20,15), title = 'Cargo-2019(unit=ton)')

# %%
#공항별 전년대비-화물(ton) 수 - 2020

# %%
f6_drop1 = f6.drop(['Increase/decrease'], axis = 1)
f6_drop1
f6__drop2 = f6_drop1.drop(['2019.1', '2019.2', '2019.3', '2019.4', '2019.5', '2019.6'], axis = 1)
f6__drop2.plot(kind = 'bar', figsize = (20,15), title = 'Cargo-2020(unit=ton)')

# %%
#공항별 전년대비-화물(ton) 증감률

# %%
f6_drop2 = f6.drop(['2019.1', '2019.2', '2019.3', '2019.4', '2019.5', '2019.6', '2020.1', '2020.2', '2020.3', '2020.4', '2020.5', '2020.6'], axis = 1)
f6_drop2.plot(kind = 'bar', figsize = (20, 15), title = 'Cargo-Increase/decrease(unit=ton) : per month')

# %%
#요일별 및 시간별 통계는 인천공항 실적을 포함하지 않음에 따라 분석하지 않았음.
#더 많은 데이터들을 알아보고 싶다면 한국공항공사 홈페이지 : 항공통계 부분을 참고바람.
