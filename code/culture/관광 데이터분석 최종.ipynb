# %%
# !git clone https://github.com/Open-Knowledge-Korea/covid-19-our-memory.git
# Out:
# Cloning into 'covid-19-our-memory'...
# remote: Enumerating objects: 135, done.
# remote: Counting objects: 100% (135/135), done.
# remote: Compressing objects: 100% (110/110), done.
# remote: Total 1391 (delta 46), reused 94 (delta 25), pack-reused 1256
# Receiving objects: 100% (1391/1391), 691.37 MiB | 34.69 MiB/s, done.
# Resolving deltas: 100% (505/505), done.
# Checking out files: 100% (989/989), done.

# %%
# !ls -ltr
# Out:
# total 76
# drwxr-xr-x  1 root root  4096 Jul 10 16:29 sample_data
# -rw-r--r--  1 root root 67061 Jul 24 12:57 a.xlsx
# drwxr-xr-x 12 root root  4096 Jul 24 13:47 covid-19-our-memory

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#관광 입국 통계

# %%
#file_used = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/whole-countries/2019.1~2020.5.xlsx
G_total = pd.read_excel('/content/2019.1~2020.5.xlsx', encoding = 'utf-8')
Total = G_total[0:3]
Total_drop = Total.drop(['국가명', 'Country', '2019년', '2020년'], axis = 1)
Total_df = np.transpose(Total_drop)
Total_df
col_name = ['G.TOTAL', 'Foreign Visitors', 'Overseas Korean']
Total_df.columns = col_name
index_name = ['2019. 1.', '2019. 2.','2019. 3.','2019. 4.','2019. 5.','2019. 6.', '2019. 7.','2019. 8.','2019. 9.','2019.10.','2019.11.', '2019.12.','2020. 1.','2020. 2.','2020. 3.','2020. 4.','2020. 5.']
Total_df.index = index_name
Total_df
# Out:
#             G.TOTAL  Foreign Visitors  Overseas Korean
# 2019. 1.  1104803.0         1089277.0          15526.0
# 2019. 2.  1201802.0         1187343.0          14459.0
# 2019. 3.  1535641.0         1516416.0          19225.0
# 2019. 4.  1635066.0         1614892.0          20174.0
# 2019. 5.  1485684.0         1466896.0          18788.0
# 2019. 6.  1476218.0         1459107.0          17111.0
# 2019. 7.  1448067.0         1432480.0          15587.0
# 2019. 8.  1586299.0         1569739.0          16560.0
# 2019. 9.  1459664.0         1443045.0          16619.0
# 2019.10.  1656195.0         1638256.0          17939.0
# 2019.11.  1456429.0         1441196.0          15233.0
# 2019.12.  1456888.0         1451607.0           5281.0
# 2020. 1.  1272708.0         1263916.0           8792.0
# 2020. 2.   685212.0          677603.0           7609.0
# 2020. 3.    83497.0           81882.0           1615.0
# 2020. 4.    29415.0           28717.0            698.0
# ...

# %%
plt.figure(figsize=(20,10))
plt.plot(Total_df)

# %%
fig, ax = plt.subplots(3, 1, figsize=(20, 20))

#g.total
ax[0].plot(Total_df['G.TOTAL'], color='C0') 
ax[0].set_title("G.TOTAL(unit=persons)") 
ax[0].set_xlabel("time") 
ax[0].set_ylabel("figures")

#Foregin Visitors
ax[1].plot(Total_df['Foreign Visitors'], color='C1') 
ax[1].set_title('Foreign Visitors(unit=persons)') 
ax[1].set_xlabel("time") 
ax[1].set_ylabel("figures") 

#Overseas Korean
ax[2].plot(Total_df['Overseas Korean'], color='G') 
ax[2].set_title("Overseas Korean(unit=persons)") 
ax[2].set_xlabel("time") 
ax[2].set_ylabel("figures") 
plt.show()

# %%
#성별 입국 통계

# %%
#file_used 1 = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/monthly_statistical_report/202001.xlsx
#file_used 2 = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/monthly_statistical_report/202002.xlsx
#file_used 3 = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/monthly_statistical_report/202003.xlsx
#file_used 4 = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/monthly_statistical_report/202004.xlsx
#file_used 5 = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/monthly_statistical_report/202005.xlsx
month_1 = pd.read_excel('/content/202001.xlsx', encoding = 'utf-8')
month_2 = pd.read_excel('/content/202002.xlsx', encoding = 'utf-8')
month_3 = pd.read_excel('/content/202003.xlsx', encoding = 'utf-8')
month_4 = pd.read_excel('/content/202004.xlsx', encoding = 'utf-8')
month_5 = pd.read_excel('/content/202005.xlsx', encoding = 'utf-8')
ab1 = month_1[2:3]
ab2 = month_2[2:3]
ab3 = month_3[2:3]
ab4 = month_4[2:3]
ab5 = month_5[2:3]
a2 = ab1.append(ab2)
b2 = a2.append(ab3)
c2 = b2.append(ab4)
d2 = c2.append(ab5)
d2_drop = d2.drop(['성별국적별입국  (2020년 1월)', 'Unnamed: 1','Unnamed: 2', 'Unnamed: 3','Unnamed: 4','Unnamed: 5' ,'성별국적별입국  (2020년 2월)', '성별국적별입국  (2020년 3월)', '성별국적별입국  (2020년 4월)', '성별국적별입국  (2020년 5월)' ], axis = 1)
d2_drop
col_name = ['men number', 'men increase/decrease', 'women number', 'women increase/decrease', 'crew member number', 'crew member increase/decrease']
d2_drop.columns = col_name
index_name = ['2020. 1.','2020. 2.','2020. 3.','2020. 4.','2020. 5.']
d2_drop.index = index_name
d2_drop
# Out:
#          men number  ... crew member increase/decrease
# 2020. 1.     501521  ...                           0.1
# 2020. 2.     283669  ...                         -24.4
# 2020. 3.      37484  ...                         -79.8
# 2020. 4.      11655  ...                         -90.6
# 2020. 5.      11874  ...                         -86.8
#
# [5 rows x 6 columns]

# %%
#수
fig, ax = plt.subplots(3, 1, figsize=(20, 20))

#men number
ax[0].plot(d2_drop['men number'], color='C0') 
ax[0].set_title("men number(unit=persons)") 
ax[0].set_xlabel("time") 
ax[0].set_ylabel("figures")

#women number
ax[1].plot(d2_drop['women number'], color='C1') 
ax[1].set_title("women number(unit=persons)") 
ax[1].set_xlabel("time") 
ax[1].set_ylabel("figures") 

#crew memeber number
ax[2].plot(d2_drop['crew member number'], color='G') 
ax[2].set_title("crew member number(unit=persons)") 
ax[2].set_xlabel("time") 
ax[2].set_ylabel("figures")
plt.show()

# %%
#증감
fig, ax = plt.subplots(3, 1, figsize=(20, 20))

#men increase/decrease
ax[0].plot(d2_drop['men increase/decrease'], color='C0') 
ax[0].set_title("men increase/decrease(unit=%)") 
ax[0].set_xlabel("time") 
ax[0].set_ylabel("figures")

#women increase/decrease
ax[1].plot(d2_drop['women increase/decrease'], color='C1') 
ax[1].set_title("women increase/decrease(unit=%)") 
ax[1].set_xlabel("time") 
ax[1].set_ylabel("figures")

#crew member increase/decrease
ax[2].plot(d2_drop['crew member increase/decrease'], color='G') 
ax[2].set_title("crew member increase/decrease(unit=%)") 
ax[2].set_xlabel("time") 
ax[2].set_ylabel("figures")
plt.show()

# %%
#연령별 입국 통계

# %%
#file_used 1 = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/monthly_statistical_report/202001.xlsx
#file_used 2 = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/monthly_statistical_report/202002.xlsx
#file_used 3 = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/monthly_statistical_report/202003.xlsx
#file_used 4 = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/monthly_statistical_report/202004.xlsx
#file_used 5 = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/monthly_statistical_report/202005.xlsx
month_11 = pd.read_excel('/content/통계월보_202001.xlsx', sheet_name = '연령별 입국(1월)', encoding = 'utf-8')
month_22 = pd.read_excel('/content/통계월보_202002.xlsx', sheet_name = '연령별 입국(2월)', encoding = 'utf-8')
month_33 = pd.read_excel('/content/통계월보_202003.xlsx', sheet_name = '연령별 입국(3월)', encoding = 'utf-8')
month_44 = pd.read_excel('/content/통계월보_202004.xlsx', sheet_name = '연령별 입국(4월)', encoding = 'utf-8')
month_55 = pd.read_excel('/content/통계월보_202005.xlsx', sheet_name = '연령별 입국(5월)', encoding = 'utf-8')
bc1 = month_11[2:3]
bc2 = month_22[2:3]
bc3 = month_33[2:3]
bc4 = month_44[2:3]
bc5 = month_55[2:3]
a3 = bc1.append(bc2)
b3 = a3.append(bc3)
c3 = b3.append(bc4)
d3 = c3.append(bc5)
d3_drop = d3.drop(['연령별국적별입국  (2020년 1월)', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', '연령별국적별입국  (2020년 2월)', '연령별국적별입국  (2020년 3월)', '연령별국적별입국  (2020년 4월)', '연령별국적별입국  (2020년 5월)'], axis = 1)
col_name = ['0~20', 'increase/decrease1', '21~30','increase/decrease2', '31~40', 'increase/decrease3', '41~50', 'increase/decrease4', '51~60', 'increase/decrease5', '61~','increase/decrease6', 'crew member', 'increase/decrease7']
d3_drop.columns = col_name
index_name = ['2020. 1.','2020. 2.','2020. 3.','2020. 4.','2020. 5.']
d3_drop.index = index_name
d3_drop
# Out:
#             0~20 increase/decrease1  ... crew member increase/decrease7
# 2020. 1.  129410               17.4  ...       79320                0.1
# 2020. 2.   44270              -62.1  ...       52460              -24.4
# 2020. 3.    3903              -97.4  ...       16785              -79.8
# 2020. 4.    1813              -98.5  ...        9226              -90.6
# 2020. 5.    1919                -98  ...       12864              -86.8
#
# [5 rows x 14 columns]

# %%
#수
fig, ax = plt.subplots(7, 1, figsize=(20, 25))

#0~20 number
ax[0].plot(d3_drop['0~20'], color='C0') 
ax[0].set_title("0~20(unit=persons)") 
ax[0].set_xlabel("time") 
ax[0].set_ylabel("figures")

#21~30 number
ax[1].plot(d3_drop['21~30'], color='C1') 
ax[1].set_title("21~30(unit=persons)") 
ax[1].set_xlabel("time") 
ax[1].set_ylabel("figures") 

#31~40 number
ax[2].plot(d3_drop['31~40'], color='G') 
ax[2].set_title("31~40(unit=persons)") 
ax[2].set_xlabel("time") 
ax[2].set_ylabel("figures") 

#41~50 number
ax[3].plot(d3_drop['41~50'], color='R') 
ax[3].set_title("41~50(unit=persons)") 
ax[3].set_xlabel("time") 
ax[3].set_ylabel("figures") 

#51~60 number
ax[4].plot(d3_drop['51~60'], color='y') 
ax[4].set_title("51~60(unit=persons)") 
ax[4].set_xlabel("time") 
ax[4].set_ylabel("figures") 

#61~ number
ax[5].plot(d3_drop['61~'], color='m') 
ax[5].set_title("61~(unit=persons)") 
ax[5].set_xlabel("time") 
ax[5].set_ylabel("figures") 

#crew member number
ax[6].plot(d3_drop['crew member'], color='k') 
ax[6].set_title("crew member(unit=persons)") 
ax[6].set_xlabel("time") 
ax[6].set_ylabel("figures") 
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/pylabtools.py:125: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#증감
fig, ax = plt.subplots(7, 1, figsize=(20, 20))

#0~20 increase/decrease
ax[0].plot(d3_drop['increase/decrease1'], color='C0') 
ax[0].set_title("0~20 increase/decrease(unit=%)") 
ax[0].set_xlabel("time") 
ax[0].set_ylabel("figures")

#21~30 increase/decrease
ax[1].plot(d3_drop['increase/decrease2'], color='C1') 
ax[1].set_title("21~30 increase/decrease(unit=%)") 
ax[1].set_xlabel("time") 
ax[1].set_ylabel("figures") 

#31~40 increase/decrease
ax[2].plot(d3_drop['increase/decrease3'], color='G') 
ax[2].set_title("31~40 increase/decrease(unit=%)") 
ax[2].set_xlabel("time") 
ax[2].set_ylabel("figures") 

#41~50 increase/decrease
ax[3].plot(d3_drop['increase/decrease4'], color='R') 
ax[3].set_title("41~50 increase/decrease(unit=%)") 
ax[3].set_xlabel("time") 
ax[3].set_ylabel("figures") 

#51~60 increase/decrease
ax[4].plot(d3_drop['increase/decrease5'], color='y') 
ax[4].set_title("51~60 increase/decrease(unit=%)") 
ax[4].set_xlabel("time") 
ax[4].set_ylabel("figures") 

#61~ increase/decrease
ax[5].plot(d3_drop['increase/decrease6'], color='m') 
ax[5].set_title("61~ increase/decrease(unit=%)") 
ax[5].set_xlabel("time") 
ax[5].set_ylabel("figures") 

#crew member increase/decrease
ax[6].plot(d3_drop['increase/decrease7'], color='k') 
ax[6].set_title("crew member increase/decrease(unit=%)") 
ax[6].set_xlabel("time") 
ax[6].set_ylabel("figures") 
plt.show()

# %%
#목적별 입국

# %%
#file_used 1 = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/monthly_statistical_report/%ED%86%B5%EA%B3%84%EC%9B%94%EB%B3%B4_202001.xlsx
#file_used 2 = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/monthly_statistical_report/%ED%86%B5%EA%B3%84%EC%9B%94%EB%B3%B4_202002.xlsx
#file_used 3 = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/monthly_statistical_report/%ED%86%B5%EA%B3%84%EC%9B%94%EB%B3%B4_202003.xlsx
#file_used 4 = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/monthly_statistical_report/%ED%86%B5%EA%B3%84%EC%9B%94%EB%B3%B4_202004.xlsx
#file_used 5 = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/monthly_statistical_report/%ED%86%B5%EA%B3%84%EC%9B%94%EB%B3%B4_202005.xlsx
month__1 = pd.read_excel('/content/202001.xlsx', sheet_name = '목적별 입국(1월)', encoding = 'utf-8')
month__2 = pd.read_excel('/content/202002.xlsx', sheet_name = '목적별 입국(2월)', encoding = 'utf-8')
month__3 = pd.read_excel('/content/202003.xlsx', sheet_name = '목적별 입국(3월)', encoding = 'utf-8')
month__4 = pd.read_excel('/content/202004.xlsx', sheet_name = '목적별 입국(4월)', encoding = 'utf-8')
month__5 = pd.read_excel('/content/202005.xlsx', sheet_name = '목적별 입국(5월)', encoding = 'utf-8')
cd1 = month__1[2:3]
cd2 = month__2[2:3]
cd3 = month__3[2:3]
cd4 = month__4[2:3]
cd5 = month__5[2:3]
a4 = cd1.append(cd2)
b4 = a4.append(cd3)
c4 = b4.append(cd4)
d4 = c4.append(cd5)
d4_drop = d4.drop(['목적별국적별입국  (2020년 1월)', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3','Unnamed: 4', 'Unnamed: 5' , '목적별국적별입국  (2020년 2월)', '목적별국적별입국  (2020년 3월)', '목적별국적별입국  (2020년 4월)', '목적별국적별입국  (2020년 5월)'], axis = 1)
col_name = ['travel', 'increase/decrease1', 'commercial','increase/decrease2', 'public', 'increase/decrease3', 'study', 'increase/decrease4', 'etc', 'increase/decrease5']
d4_drop.columns = col_name
index_name = ['2020. 1.','2020. 2.','2020. 3.','2020. 4.','2020. 5.']
d4_drop.index = index_name
d4_drop
# Out:
#            travel increase/decrease1  ...     etc increase/decrease5
# 2020. 1.  1030497               16.5  ...  202821                8.8
# 2020. 2.   503976              -44.5  ...  128715              -39.4
# 2020. 3.    31497              -97.5  ...   35790              -83.5
# 2020. 4.     5135              -99.6  ...   16551              -92.4
# 2020. 5.     6111              -99.5  ...   21870              -89.6
#
# [5 rows x 10 columns]

# %%
#수
fig, ax = plt.subplots(5, 1, figsize=(20, 20))

#travel number
ax[0].plot(d4_drop['travel'], color='C0') 
ax[0].set_title("travel(unit=persons)") 
ax[0].set_xlabel("time") 
ax[0].set_ylabel("figures")

#commercial number
ax[1].plot(d4_drop['commercial'], color='C1') 
ax[1].set_title("commercial(unit=persons)") 
ax[1].set_xlabel("time") 
ax[1].set_ylabel("figures") 

#public number
ax[2].plot(d4_drop['public'], color='G') 
ax[2].set_title("public(unit=persons)") 
ax[2].set_xlabel("time") 
ax[2].set_ylabel("figures") 

#study number
ax[3].plot(d4_drop['study'], color='R') 
ax[3].set_title("study(unit=persons)") 
ax[3].set_xlabel("time") 
ax[3].set_ylabel("figures") 

#etc number
ax[4].plot(d4_drop['etc'], color='y') 
ax[4].set_title("etc(unit=persons)") 
ax[4].set_xlabel("time") 
ax[4].set_ylabel("figures") 
plt.show()

# %%
#증감
fig, ax = plt.subplots(5, 1, figsize=(20, 20))

#travel increase/decrease
ax[0].plot(d3_drop['increase/decrease1'], color='C0') 
ax[0].set_title("travel increase/decrease(unit=%)") 
ax[0].set_xlabel("time") 
ax[0].set_ylabel("figures")

#commercial increase/decrease
ax[1].plot(d4_drop['increase/decrease2'], color='C1') 
ax[1].set_title("comercial increase/decrease(unit=%)") 
ax[1].set_xlabel("time") 
ax[1].set_ylabel("figures") 

#public increase/decrease
ax[2].plot(d4_drop['increase/decrease3'], color='G') 
ax[2].set_title("public increase/decrease(unit=%)") 
ax[2].set_xlabel("time") 
ax[2].set_ylabel("figures") 

#study increase/decrease
ax[3].plot(d4_drop['increase/decrease4'], color='R') 
ax[3].set_title("study increase/decrease(unit=%)") 
ax[3].set_xlabel("time") 
ax[3].set_ylabel("figures") 

#etc increase/decrease
ax[4].plot(d4_drop['increase/decrease5'], color='y') 
ax[4].set_title("etc increase/decrease(unit=%)") 
ax[4].set_xlabel("time") 
ax[4].set_ylabel("figures") 
plt.show()

# %%
#관광 출국 통계

# %%
#file_used = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/whole-countries/2019.1~2020.5.xlsx
D_total = pd.read_excel('/content/2019.1~2020.5.xlsx', sheet_name = '출국', encoding = 'utf-8')
df1 = D_total[0:3]
df1_drop = df1.drop(['Destination', '행선국', '2019년', '2020년'], axis = 1)
df2 = np.transpose(df1_drop)
col_name = ['G.TOTAL', 'Departures Korean', 'Crew']
df2.columns = col_name
index_name = ['2019. 1.', '2019. 2.','2019. 3.','2019. 4.','2019. 5.','2019. 6.', '2019. 7.','2019. 8.','2019. 9.','2019.10.','2019.11.', '2019.12.','2020. 1.','2020. 2.','2020. 3.','2020. 4.','2020. 5.']
df2.index = index_name
df2
# Out:
#             G.TOTAL  Departures Korean      Crew
# 2019. 1.  2912331.0          2753749.0  158582.0
# 2019. 2.  2617946.0          2474407.0  143539.0
# 2019. 3.  2334153.0          2180647.0  153506.0
# 2019. 4.  2246417.0          2096813.0  149604.0
# 2019. 5.  2401204.0          2245277.0  155927.0
# 2019. 6.  2495798.0          2344893.0  150905.0
# 2019. 7.  2642585.0          2486739.0  155846.0
# 2019. 8.  2427634.0          2270559.0  157075.0
# 2019. 9.  2049830.0          1908662.0  141168.0
# 2019.10.  2153847.0          2009817.0  144030.0
# 2019.11.  2090192.0          1952220.0  137972.0
# 2019.12.  2342310.0          2196632.0  145678.0
# 2020. 1.  2513030.0          2357829.0  155201.0
# 2020. 2.  1046779.0           928970.0  117809.0
# 2020. 3.   143366.0           101069.0   42297.0
# 2020. 4.    31425.0             5838.0   25587.0
# 2020. 5.    37801.0            11418.0   26383.0

# %%
plt.figure(figsize=(20,10))
plt.plot(df2)

# %%
fig, ax = plt.subplots(3, 1, figsize=(20, 20))

#g.total
ax[0].plot(df2['G.TOTAL'], color='C0') 
ax[0].set_title("G.TOTAL(unit=persons)") 
ax[0].set_xlabel("time") 
ax[0].set_ylabel("figures")

#Departures Korean
ax[1].plot(df2['Departures Korean'], color='C1') 
ax[1].set_title("Departures Korean(unit=persons)") 
ax[1].set_xlabel("time") 
ax[1].set_ylabel("figures") 

#Crew
ax[2].plot(df2['Crew'], color='G') 
ax[2].set_title("Crew") 
ax[2].set_xlabel("time") 
ax[2].set_ylabel("figures") 
plt.show()

# %%
#성별 출국 통계

# %%
#file_used = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/monthly_statistical_report/202005.xlsx
month___5 = pd.read_excel('/content/202005.xlsx', sheet_name = '성별 출국', encoding = 'utf-8')
fg = month___5[2:8]
fg_drop = fg.drop(['성별출국', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'], axis = 1)
fg_drop
col_name = ['men number', 'men increase/decrease', 'women number','women increase/decrease', 'crew member number', 'crew member increase/decrease']
fg_drop.columns = col_name
index_name = ['total', '2020. 1.','2020. 2.','2020. 3.','2020. 4.','2020. 5.']
fg_drop.index = index_name
fg_drop
# Out:
#          men number  ... crew member increase/decrease
# total       1787212  ...                         -51.7
# 2020. 1.    1205522  ...                          -2.1
# 2020. 2.     509793  ...                         -17.9
# 2020. 3.      58609  ...                         -72.4
# 2020. 4.       4455  ...                         -82.9
# 2020. 5.       8833  ...                         -83.1
#
# [6 rows x 6 columns]

# %%
#수
fig, ax = plt.subplots(3, 1, figsize=(20, 20))

#men number
ax[0].plot(fg_drop['men number'], color='C0') 
ax[0].set_title("men number(unit=persons)") 
ax[0].set_xlabel("time") 
ax[0].set_ylabel("figures")

#women number
ax[1].plot(fg_drop['women number'], color='C1') 
ax[1].set_title("women number(unit=persons)") 
ax[1].set_xlabel("time") 
ax[1].set_ylabel("figures") 

#crew memeber number
ax[2].plot(fg_drop['crew member number'], color='G') 
ax[2].set_title("crew member number(unit=persons)") 
ax[2].set_xlabel("time") 
ax[2].set_ylabel("figures")
plt.show()

# %%
#증감
fig, ax = plt.subplots(3, 1, figsize=(20, 20))

#men increase/decrease
ax[0].plot(d2_drop['men increase/decrease'], color='C0') 
ax[0].set_title("men increase/decrease(unit=%)") 
ax[0].set_xlabel("time") 
ax[0].set_ylabel("figures")

#women increase/decrease
ax[1].plot(d2_drop['women increase/decrease'], color='C1') 
ax[1].set_title("women increase/decrease(unit=%)") 
ax[1].set_xlabel("time") 
ax[1].set_ylabel("figures")

#crew member increase/decrease
ax[2].plot(d2_drop['crew member increase/decrease'], color='G') 
ax[2].set_title("crew member increase/decrease(unit=%)") 
ax[2].set_xlabel("time") 
ax[2].set_ylabel("figures")
plt.show()

# %%
#연령별 출국

# %%
#file_used 5 = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/monthly_statistical_report/202005.xlsx
month____5 = pd.read_excel('/content/202005.xlsx', sheet_name = '연령별 출국', encoding = 'utf-8')
gh = month____5[2:8]
gh_drop = gh.drop(['연령별출국', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'], axis = 1)
col_name = ['0~20', 'increase/decrease1', '21~30','increase/decrease2', '31~40', 'increase/decrease3', '41~50', 'increase/decrease4', '51~60', 'increase/decrease5', '61~','increase/decrease6', 'crew member', 'increase/decrease7']
gh_drop.columns = col_name
index_name = ['total', '2020. 1.','2020. 2.','2020. 3.','2020. 4.','2020. 5.']
gh_drop.index = index_name
gh_drop
# Out:
#             0~20 increase/decrease1  ... crew member increase/decrease7
# total     510275                -67  ...      367277              -51.7
# 2020. 1.  374797              -28.6  ...      155201               -2.1
# 2020. 2.  122155              -71.1  ...      117809              -17.9
# 2020. 3.   12408                -92  ...       42297              -72.4
# 2020. 4.     300              -99.8  ...       25587              -82.9
# 2020. 5.     615              -99.8  ...       26383              -83.1
#
# [6 rows x 14 columns]

# %%
#수
fig, ax = plt.subplots(7, 1, figsize=(20, 20))

#0~20 number
ax[0].plot(gh_drop['0~20'], color='C0') 
ax[0].set_title("0~20(unit=persons)") 
ax[0].set_xlabel("time") 
ax[0].set_ylabel("figures")

#21~30 number
ax[1].plot(gh_drop['21~30'], color='C1') 
ax[1].set_title("21~30(unit=persons)") 
ax[1].set_xlabel("time") 
ax[1].set_ylabel("figures") 

#31~40 number
ax[2].plot(gh_drop['31~40'], color='G') 
ax[2].set_title("31~40(unit=persons)") 
ax[2].set_xlabel("time") 
ax[2].set_ylabel("figures") 

#41~50 number
ax[3].plot(gh_drop['41~50'], color='R') 
ax[3].set_title("41~50(unit=persons)") 
ax[3].set_xlabel("time") 
ax[3].set_ylabel("figures") 

#51~60 number
ax[4].plot(gh_drop['51~60'], color='y') 
ax[4].set_title("51~60(unit=persons)") 
ax[4].set_xlabel("time") 
ax[4].set_ylabel("figures") 

#61~ number
ax[5].plot(gh_drop['61~'], color='m') 
ax[5].set_title("61~(unit=persons)") 
ax[5].set_xlabel("time") 
ax[5].set_ylabel("figures") 

#crew member number
ax[6].plot(gh_drop['crew member'], color='k') 
ax[6].set_title("crew member(unit=persons)") 
ax[6].set_xlabel("time") 
ax[6].set_ylabel("figures") 
plt.show()

# %%
#증감
fig, ax = plt.subplots(7, 1, figsize=(20, 20))

#0~20 increase/decrease
ax[0].plot(gh_drop['increase/decrease1'], color='C0') 
ax[0].set_title("0~20 increase/decrease(unit=%)") 
ax[0].set_xlabel("time") 
ax[0].set_ylabel("figures")

#21~30 increase/decrease
ax[1].plot(gh_drop['increase/decrease2'], color='C1') 
ax[1].set_title("21~30 increase/decrease(unit=%)") 
ax[1].set_xlabel("time") 
ax[1].set_ylabel("figures") 

#31~40 increase/decrease
ax[2].plot(gh_drop['increase/decrease3'], color='G') 
ax[2].set_title("31~40 increase/decrease(unit=%)") 
ax[2].set_xlabel("time") 
ax[2].set_ylabel("figures") 

#41~50 increase/decrease
ax[3].plot(gh_drop['increase/decrease4'], color='R') 
ax[3].set_title("41~50 increase/decrease(unit=%)") 
ax[3].set_xlabel("time") 
ax[3].set_ylabel("figures") 

#51~60 increase/decrease
ax[4].plot(gh_drop['increase/decrease5'], color='y') 
ax[4].set_title("51~60 increase/decrease(unit=%)") 
ax[4].set_xlabel("time") 
ax[4].set_ylabel("figures") 

#61~ increase/decrease
ax[5].plot(gh_drop['increase/decrease6'], color='m') 
ax[5].set_title("61~ increase/decrease(unit=%)") 
ax[5].set_xlabel("time") 
ax[5].set_ylabel("figures") 

#crew member increase/decrease
ax[6].plot(gh_drop['increase/decrease7'], color='k') 
ax[6].set_title("crew member increase/decrease(unit=%)") 
ax[6].set_xlabel("time") 
ax[6].set_ylabel("figures") 
plt.show()

# %%
#전년대비통계-전체 방한 외래 관광객 수

# %%
#file_used1 = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/major-countries/major_countries_202001.xlsx
#file_used2 = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/major-countries/major_countries_202002.xlsx
#file_used3 = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/major-countries/major_countries_202003.xlsx
#file_used4 = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/major-countries/major_countries_202004.xlsx
#file_used5 = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/major-countries/major_countries_202005.xlsx
month1 = pd.read_excel('/content/major_countries_202001.xlsx', encoding = 'utf-8')
month2 = pd.read_excel('/content/major_countries_202002.xlsx', encoding = 'utf-8')
month3 = pd.read_excel('/content/major_countries_202003.xlsx', encoding = 'utf-8')
month4 = pd.read_excel('/content/major_countries_202004.xlsx', encoding = 'utf-8')
month5 = pd.read_excel('/content/major_countries_202005.xlsx', encoding = 'utf-8')
df3 = month1[3:4]
df3_drop = df3.drop(['2020. 1. 관광통계', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 5'], axis = 1)
df4 = month2[3:4]
df4_drop = df4.drop(['2020. 2. 관광통계', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'], axis = 1)
df5 = month3[3:4]
df5_drop = df5.drop(['2020. 3. 관광통계', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'], axis = 1)
df6 = month4[3:4]
df6_drop = df6.drop(['2020. 4. 관광통계', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'], axis = 1)
df7 = month5[3:4]
df7_drop = df7.drop(['2020. 5. 관광통계', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'], axis = 1)
a = df3_drop.append(df4_drop)
b = a.append(df5_drop)
c = b.append(df6_drop)
d = c.append(df7_drop)
col_name = ['성장률']
d.columns = col_name
index_name = ['2020. 1.','2020. 2.','2020. 3.','2020. 4.','2020. 5.']
d.index = index_name
d
# Out:
#               성장률
# 2020. 1.  15.1977
# 2020. 2. -42.9846
# 2020. 3. -94.5627
# 2020. 4.  -98.201
# 2020. 5. -97.9228

# %%
plt.plot(d)

# %%
#전년대비통계 - 전체 국민 해외관광객 수

# %%
dt1 = month1[4:5]
dt1_drop = dt1.drop(['2020. 1. 관광통계', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 5'], axis = 1)
dt2 = month2[4:5]
dt2_drop = dt2.drop(['2020. 2. 관광통계', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'], axis = 1)
dt3 = month3[4:5]
dt3_drop = dt3.drop(['2020. 3. 관광통계', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'], axis = 1)
dt4 = month4[4:5]
dt4_drop = dt4.drop(['2020. 4. 관광통계', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'], axis = 1)
dt5 = month5[4:5]
dt5_drop = dt5.drop(['2020. 5. 관광통계', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'], axis = 1)
a1 = dt1_drop.append(dt2_drop)
b1 = a1.append(dt3_drop)
c1 = b1.append(dt4_drop)
d1 = c1.append(dt5_drop)
col_name = ['성장률']
d1.columns = col_name
index_name = ['2020. 1.','2020. 2.','2020. 3.','2020. 4.','2020. 5.']
d1.index = index_name
d1
# Out:
#               성장률
# 2020. 1. -13.7107
# 2020. 2. -60.0153
# 2020. 3. -93.8579
# 2020. 4. -98.6011
# 2020. 5. -98.4257

# %%
plt.plot(d1)

# %%
#1~5월 주요국가 종합 통계

# %%
df8 = month5[3:5]
df8_drop = df8.drop(['2020. 5. 관광통계', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5'], axis = 1)
col_name = ['2020', '2019', '성장률', '구성비']
df8_drop.columns = col_name
index_name = ['전체 방한 외래관광객 수','전체 국민 해외관광객 수']
df8_drop.index = index_name
df8_drop
# Out:
#                   2020        2019      성장률  구성비
# 전체 방한 외래관광객 수  2101693   6962996.0 -69.8163  100
# 전체 국민 해외관광객 수  3772401  12512051.0 -69.8499  100

# %%
#2019.1 ~ 2020.5월 관광 수입 및 지출 통계
#단위 : US$백만, %
#2019년 및 2020년 관광수입.지출은 잠정치
#5월 관광수입·지출은 자료반영의 시차 관계로 3~4월 실적이 일부 포함되어 3~4월 관광객 감소가 부분적으로 반영됨(차후 수정 예정). 또한, 4월 관광수입이 변경되었음에 유의

# %%
#file_used = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/Monthly_Income%26Expenditure/tourism_income%26expenditure.xlsx
data = pd.read_excel('/content/tourism_income&expenditure.xlsx', encoding = 'utf-8')
data1 = data[:]
data1_drop = data1.drop(['구분', '외래객 입국수', '증감', '국민 해외여행객 수', '증감.1'], axis = 1)
data1_drop
col_name = ['income', 'increase/decrease1', 'expenditure','increase/decrease2']
data1_drop.columns = col_name
index_name = ['2019','2019. 1.', '2019. 2.','2019. 3.','2019. 4.','2019. 5.','2019. 6.', '2019. 7.','2019. 8.','2019. 9.','2019.10.','2019.11.', '2019.12.', '2020', '2020. 1.','2020. 2.','2020. 3.','2020. 4.','2020. 5.']
data1_drop.index = index_name
data2 = data1_drop.drop(['2019','2020'])
data2
# Out:
#           income  increase/decrease1  expenditure  increase/decrease2
# 2019. 1.  1548.8                24.8       2686.6               -14.5
# 2019. 2.  1554.4                21.7       2204.0               -14.0
# 2019. 3.  2227.9                40.1       2195.7               -19.6
# 2019. 4.  2098.0                22.4       2308.9                -7.6
# 2019. 5.  1923.6                19.1       2453.4                -8.8
# 2019. 6.  1543.9                -7.5       2445.4                -3.9
# 2019. 7.  1749.6                17.6       2562.5                -1.0
# 2019. 8.  1853.6                18.7       2424.4                -9.9
# 2019. 9.  1708.1                12.2       2227.4                -8.2
# 2019.10.  1788.4                -3.4       2369.0                -5.3
# 2019.11.  1627.0                16.1       2354.7                -6.7
# 2019.12.  1883.0                23.0       2623.4                -0.3
# ...

# %%
fig, ax = plt.subplots(4, 1, figsize=(20, 20))

#수
#income 
ax[0].plot(data2['income'], color='C0') 
ax[0].set_title("income(unit=US$ million)") 
ax[0].set_xlabel("time") 
ax[0].set_ylabel("figures")

#expenditure
ax[1].plot(data2['expenditure'], color='C1') 
ax[1].set_title("expenditure(unit=US$ million)") 
ax[1].set_xlabel("time") 
ax[1].set_ylabel("figures") 

#증감
#income increase/decrease
ax[2].plot(data2['increase/decrease1'], color='G') 
ax[2].set_title("income increase/decrease(unit=%)") 
ax[2].set_xlabel("time") 
ax[2].set_ylabel("figures") 

#expenditure increase/decrease
ax[3].plot(data2['increase/decrease2'], color='R') 
ax[3].set_title("expenditure increase/decrease(unit=%)") 
ax[3].set_xlabel("time") 
ax[3].set_ylabel("figures")
plt.show()

# %%
#2020 1~5월 1인당 관광 수입 및 지출

# %%
#file_used = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/Monthly_Income%26Expenditure/tourism_income%26expenditure.xlsx
data3 = pd.read_excel('/content/tourism_income&expenditure.xlsx', sheet_name = '1인당 지출액', encoding = 'utf-8')
col_name = ['income', 'increase/decrease1', 'expenditure','increase/decrease2']
data3.columns = col_name
index_name = ['2020. 1.','2020. 2.','2020. 3.','2020. 4.','2020. 5.']
data3.index = index_name
data3
# Out:
#           income  increase/decrease1  expenditure  increase/decrease2
# 2020. 1.    1241               -11.5          998                 8.2
# 2020. 2.    1675                29.5         1355                60.9
# 2020. 3.    8740               502.5         6149               553.6
# 2020. 4.   11960               832.1        18377              1688.0
# 2020. 5.   13823               967.6        12098              1084.0

# %%
fig, ax = plt.subplots(4, 1, figsize=(20, 20))

#수
#income per person
ax[0].plot(data3['income'], color='C0') 
ax[0].set_title("income per person(unit=US$ million)") 
ax[0].set_xlabel("time") 
ax[0].set_ylabel("figures")

#expenditure per person
ax[1].plot(data3['expenditure'], color='C1') 
ax[1].set_title("expenditure per person(unit=US$ million)") 
ax[1].set_xlabel("time") 
ax[1].set_ylabel("figures") 

#증감
#income per person increase/decrease
ax[2].plot(data3['increase/decrease1'], color='G') 
ax[2].set_title("income per person increase/decrease(unit=%)") 
ax[2].set_xlabel("time") 
ax[2].set_ylabel("figures") 

#expenditure per person increase/decrease
ax[3].plot(data3['increase/decrease2'], color='R') 
ax[3].set_title("expenditure per person increase/decrease(unit=%)") 
ax[3].set_xlabel("time") 
ax[3].set_ylabel("figures")
plt.show()

# %%
#2020 1~5월 월평균환율

# %%
#file_used = https://github.com/Open-Knowledge-Korea/covid-19-our-memory/blob/master/data/culture/Tourism/Monthly_Income%26Expenditure/tourism_income%26expenditure.xlsx
data4 = pd.read_excel('/content/tourism_income&expenditure.xlsx', sheet_name = '월평균환율', encoding = 'utf-8')
index_name = ['2020. 1.','2020. 2.','2020. 3.','2020. 4.','2020. 5.']
data4.index = index_name
data4
# Out:
#           US$1=원  1위안=원
# 2020. 1.  1164.3  168.0
# 2020. 2.  1193.8  170.5
# 2020. 3.  1220.1  173.8
# 2020. 4.  1225.2  172.9
# 2020. 5.  1228.7  172.5

# %%
fig, ax = plt.subplots(2, 1, figsize=(20, 20))

#US$1=원
ax[0].plot(data4['US$1=원'], color='C0') 
ax[0].set_title("US$1=won") 
ax[0].set_xlabel("time") 
ax[0].set_ylabel("figures")

#1위안=원
ax[1].plot(data4['1위안=원'], color='C1') 
ax[1].set_title("1yuan=won") 
ax[1].set_xlabel("time") 
ax[1].set_ylabel("figures")
plt.show()
