# %% [markdown]
# # 청와대 청원 기간별 분석 코드
#
# * 작성자: 박하람
# * 청와대 청원 기간별 wordcloud 코드

# %% [markdown]
# ## 파일 불러오기

# %%
# !apt-get update 
# !apt-get install g++ openjdk-8-jdk python-dev python3-dev 
# !pip3 install JPype1-py3 
# !pip3 install konlpy 
# !JAVA_HOME="C:\Program Files\Java\jdk-13.0.2"
# !pip install wordcloud
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:6 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:8 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:10 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Ign:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages
# ...

# %%
import pandas as pd
import numpy as np 
import re

# %%
df1 = pd.read_excel('/content/corona-BlueHouse-Petition-data.xlsx', index_col=0, header=1, encoding='utf-8')
df2 = pd.read_excel('/content/코로나-BlueHouse-Petition-data.xlsx', index_col=0, header=1, encoding='utf-8')
df3 = pd.read_excel('/content/코비드-BlueHouse-Petition-data.xlsx', index_col=0, encoding='utf-8')
df4 = pd.read_excel('/content/corona-BlueHouse-Petition-data.xlsx', index_col=0, header=1, encoding='utf-8')
df5 = pd.read_excel('/content/covid-BlueHouse-Petition-data.xlsx', index_col=0, header=1, encoding='utf-8')
df6 = pd.read_excel('/content/covid19-BlueHouse-Petition-data.xlsx', index_col=0, encoding='utf-8')

# %%
print(df1.shape, df2.shape, df3.shape, df4.shape, df5.shape, df6.shape)
# Out:
# (2, 8) (2996, 8) (3, 8) (2, 8) (43, 8) (10, 8)

# %%
petition_raw = pd.concat([df1, df2, df3, df4, df5, df6])
petition_raw.shape
# Out:
# (3056, 8)

# %% [markdown]
# ## 중복 데이터 제거

# %%
petition = petition_raw.drop_duplicates()
petition.shape
# Out:
# (3022, 8)

# %% [markdown]
# ## 2020년 이전 데이터 제외

# %%
month = pd.to_datetime(petition['청원시작일']).dt.month
year = pd.to_datetime(petition['청원시작일']).dt.year
petition['월'] = month
petition['년'] = year
petition = petition.sort_values(by='월')
petition.shape
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# (3022, 10)

# %%
print('2020년 이외의 데이터: ', len(petition[petition['년'] < 2020]))
petition = petition[petition['년'] == 2020]
petition.shape
# Out:
# 2020년 이외의 데이터:  10
# (3012, 10)

# %%
petition = petition.reset_index()
petition.drop('index',1,inplace=True)

# %% [markdown]
# ## 텍스트 데이터 전처리

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import platform

from matplotlib import font_manager, rc
if platform.system() == 'Windows':
  font_name = font_manager.FontProperties(fname = font_fname).get_name()
  plt.rcParams["font.family"] = font_family

# %matplotlib inline

# %%
# %config InlineBackend.figure_format = 'retina'

# !apt -qq -y install fonts-nanum > /dev/null
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname = fontpath,size=9)
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
import nltk 
from konlpy.tag import Okt

# %%
def preprocessing(text): 
    # 개행문자 제거 
    text = re.sub('\\\n',' ', text)
    # 한글 영문만 남기고 모두 제거 (숫자, 특수문자도 제거)
    text = re.sub('[^가-힣ㄱ-ㅎㅏ-ㅣa-zA-Z]', ' ', text)
    return text

# %%
petition_feb = petition[(petition['월'] == 1) | (petition['월'] == 2)]
petition_mar = petition[petition['월'] == 3]
petition_apr = petition[petition['월'] == 4]
petition_may = petition[petition['월'] == 5]
petition_jun = petition[petition['월'] == 6]
petition_jul = petition[petition['월'] == 7]

# %%
list = [petition_feb, petition_mar, petition_apr,petition_may,petition_jun,petition_jul]

for i, name in enumerate(list): 
  name.to_csv(f'petition-{i}.csv', encoding='utf-8')

# %% [markdown]
# ## WordCloud 그리기

# %%
stop_words = ['.','을','이','의','를','에',',','가','들','은','는','으로','한','도',
              '수','에서','로','것','그','과','제','입니다','할','하고','적',"'",'하는',
              '합니다','와','에게','고','인',')','?','하여','등','저','있습니다','말','까지',
              '(','1','그리고','다','2','만','딸','했습니다','안','된','못','일','더','위',
              '있는','해','\n','또한','명','하지','..','정말','물','많은','"',
              '중','3','게','너무','A','자','이런','때','되지','위해','에는','없는',
              '및','요','때문','관련','대한','전','라고','되었습니다','하기','나','후','같은','해서',
              '글','되어','주','차','하','내','없이','대해','잘']

# %%
def make_wordcloud_data(df, stopwords): 
  okt = Okt()
  sentences = ''

  for each_line in df['청원내용']: 
    sentences = sentences + each_line + '\n'

  tokens_ko = okt.morphs(sentences)
  ko = nltk.Text(tokens_ko, name='청원내용 분석')

  data = dict(ko.vocab().most_common(150))
  return data

# %%
def make_wordcloud(data):
    wordcloud = WordCloud(font_path=fontpath,
                      max_font_size = 100, 
                      relative_scaling = 0.4,
                      background_color='white',).generate_from_frequencies(data)
    plt.figure(figsize=(10,8))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()
    plt.savefig('wordcloud image.png')

# %%
data = make_wordcloud_data(petition_feb, stop_words)

# %%
make_wordcloud(data)
